# %% [markdown]
# ## Load necessary modules

# %%
import matplotlib 
matplotlib.use('Agg')
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet.models.resnet import custom_objects
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import sys

# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this environment flag to change which GPU to use
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /scratch/user/puneetkohli/.conda/envs/puneet_keras_env/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# ## Run RetinaNet model

# %%
def run_model(image, model):
    # copy to draw on
    draw = image.copy()
    print ("Original Frame is = ", draw.shape)
    
    # preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)
    print ("Processed Frame is = ", image.shape)
    
    # process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)
    sys.stdout.flush()
    # correct for image scale
    boxes /= scale

    # visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        if score < 0.5:
            break
        print ("Found label = ", label)
        color = label_color(label)

        b = box.astype(int)
        draw_box(draw, b, color=color)

        caption = "{} {:.3f}".format(labels_to_names[label], score)
        draw_caption(draw, b, caption)

    fig = plt.figure(figsize=(12.8, 7.2))
    ax = fig.add_axes([0, 0, 1, 1])
    ax.axis('off')
    plt.imshow(draw)
    fig.canvas.draw()
    data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='') #canvas to string
    data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,)) #string to array
    data = data[:, :, ::-1]
    plt.close() 
    print("Data shape = " , data.shape)
    return data, label

# %% [markdown]
# ## Get COCO Class Names

# %%
# load label to names mapping for visualization purposes
labels_to_names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %% [markdown]
# ## Run detection on video

# %%
def run_on_video(video_path, video_name, model):
    cap = cv2.VideoCapture(video_path)
    import time
    start_time = time.time()
    fps = cap.get(cv2.CAP_PROP_FPS)
    out_path = "out_" + video_name + "_RetinaNet_2" + ".avi"
    out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc(*'XVID'), fps, (1280,720)) #width, height format
    i = 0
    people_frames = []
    while(cap.isOpened()):
        has_frame, frame = cap.read()
        if not has_frame: 
            break
        # Custom code here
        i += 1
        print ("Processing frame #", i)
        sys.stdout.flush()
        processed_img, label = run_model(frame, model)
        out.write(processed_img)
        print ("Label = ", label)
    print("--- %s seconds ---" % (time.time() - start_time))
    print("Finished reading video")
    print ("Wrote video to ", out_path)
    print ("Frames with person", people_frames)
    sys.stdout.flush()
    cap.release()
    out.release()

# %% [markdown]
# ## Run detection on image

# %%
def run_on_image(image_path, model):
    image = read_image_bgr(image_path)
    run_model(image, model)

# %% [markdown]
# ## Perform Tests

# %%
# set the modified tf session as backend in keras
keras.backend.tensorflow_backend.set_session(get_session())
## Load RetinaNet model
# adjust this to point to your downloaded/trained model
model_path = os.path.join('..', 'snapshots', 'resnet50_coco_best_v2.0.3.h5')
# load retinanet model
model = keras.models.load_model(model_path, custom_objects=custom_objects)
print("Model Loaded")
sys.stdout.flush()
#run_on_image('000000008021.jpg', model)
run_on_video("uber_trimmed.mp4", "uber_trimmed", model)
# Out:
# Model Loaded
# Processing frame # 1
# /home/puneetkohli/.local/lib/python3.6/site-packages/keras/models.py:255: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  1.256347417831421
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 2
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.495774507522583
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 3
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4960165023803711
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 4
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4944002628326416
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 5
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49475789070129395
# Found label =  0
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 6
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49665117263793945
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 7
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49361538887023926
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 8
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4976468086242676
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 9
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4975733757019043
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 10
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49762821197509766
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 11
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4934811592102051
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 12
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49602437019348145
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 13
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4941294193267822
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 14
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49333620071411133
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 15
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4948887825012207
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 16
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49648451805114746
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 17
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.494077205657959
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 18
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4948084354400635
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 19
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49484777450561523
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 20
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4952704906463623
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 21
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4964020252227783
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 22
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4967224597930908
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 23
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.492825984954834
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 24
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4969027042388916
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 25
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.495943546295166
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 26
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49736452102661133
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 27
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.496812105178833
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 28
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49596333503723145
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 29
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4964597225189209
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 30
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4965972900390625
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 31
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.495711088180542
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 32
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49475526809692383
# Data shape =  (518, 921, 3)
# Label =  65
# Processing frame # 33
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49750804901123047
# Data shape =  (518, 921, 3)
# Label =  65
# Processing frame # 34
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49498891830444336
# Data shape =  (518, 921, 3)
# Label =  65
# Processing frame # 35
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49774789810180664
# Data shape =  (518, 921, 3)
# Label =  13
# Processing frame # 36
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4974937438964844
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 37
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49685001373291016
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 38
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4965052604675293
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 39
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49877357482910156
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 40
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49825072288513184
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 41
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49643802642822266
# Data shape =  (518, 921, 3)
# Label =  60
# Processing frame # 42
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4938540458679199
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 43
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49939632415771484
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 44
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49605727195739746
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 45
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4962019920349121
# Data shape =  (518, 921, 3)
# Label =  13
# Processing frame # 46
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.497251033782959
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 47
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4940013885498047
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 48
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49414968490600586
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 49
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49522876739501953
# Data shape =  (518, 921, 3)
# Label =  43
# Processing frame # 50
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4954690933227539
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 51
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4963250160217285
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 52
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49602484703063965
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 53
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49602365493774414
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 54
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4990983009338379
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 55
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49315953254699707
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 56
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49788498878479004
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 57
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49538183212280273
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 58
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49576854705810547
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 59
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49567651748657227
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 60
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4961996078491211
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 61
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4957916736602783
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 62
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4956851005554199
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 63
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4956648349761963
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 64
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4944484233856201
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 65
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4981648921966553
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 66
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49582433700561523
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 67
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49605274200439453
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 68
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.496307373046875
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 69
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4956538677215576
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 70
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4966914653778076
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 71
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4944484233856201
# Found label =  3
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 72
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.495922327041626
# Found label =  3
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 73
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4972958564758301
# Found label =  3
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 74
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4967529773712158
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 75
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4971308708190918
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 76
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49883127212524414
# Found label =  3
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 77
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49742913246154785
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 78
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49633145332336426
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 79
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49903321266174316
# Found label =  3
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 80
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4967305660247803
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 81
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4974374771118164
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 82
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4966731071472168
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 83
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49582600593566895
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 84
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49999117851257324
# Data shape =  (518, 921, 3)
# Label =  3
# Processing frame # 85
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5052046775817871
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 86
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5051553249359131
# Found label =  1
# Data shape =  (518, 921, 3)
# Label =  0
# Processing frame # 87
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49805569648742676
# Found label =  0
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 88
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49585795402526855
# Found label =  0
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 89
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4988219738006592
# Found label =  0
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 90
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.497391939163208
# Data shape =  (518, 921, 3)
# Label =  1
# Processing frame # 91
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.498443603515625
# Found label =  2
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 92
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49352097511291504
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 93
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49520444869995117
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 94
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49722933769226074
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 95
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49769115447998047
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 96
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4972372055053711
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 97
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.497344970703125
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 98
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4968833923339844
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 99
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4957127571105957
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 100
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4968247413635254
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 101
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5012168884277344
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 102
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4955158233642578
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 103
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49541711807250977
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 104
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4971768856048584
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 105
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49715542793273926
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 106
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4978053569793701
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 107
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49718284606933594
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 108
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49811530113220215
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 109
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49489593505859375
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 110
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49930739402770996
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 111
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5005340576171875
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 112
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49680447578430176
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 113
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49634337425231934
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 114
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5001280307769775
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 115
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4973282814025879
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 116
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4981107711791992
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 117
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49724483489990234
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 118
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.499523401260376
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 119
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4970405101776123
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 120
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49724316596984863
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 121
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49714088439941406
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 122
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49564218521118164
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 123
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49678921699523926
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 124
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4961249828338623
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 125
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4970285892486572
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 126
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4960904121398926
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 127
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4983677864074707
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 128
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4970836639404297
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 129
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4976460933685303
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 130
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49649739265441895
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 131
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49799275398254395
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 132
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49592113494873047
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 133
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4973292350769043
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 134
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49648070335388184
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 135
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.498807430267334
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 136
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4984431266784668
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 137
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49844884872436523
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 138
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49875712394714355
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 139
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4960517883300781
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 140
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.494901180267334
# Data shape =  (518, 921, 3)
# Label =  2
# Processing frame # 141
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4956092834472656
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 142
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49763965606689453
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 143
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49692535400390625
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 144
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4967622756958008
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 145
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4975314140319824
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 146
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4969055652618408
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 147
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4977905750274658
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 148
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49631261825561523
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 149
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4974687099456787
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 150
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49692726135253906
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 151
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.498431921005249
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 152
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.502922773361206
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 153
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4978499412536621
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 154
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49544572830200195
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 155
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49783825874328613
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 156
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5005478858947754
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 157
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49919867515563965
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 158
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5038325786590576
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 159
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5009005069732666
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 160
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49530529975891113
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 161
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4982335567474365
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 162
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.5021350383758545
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 163
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.4994359016418457
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 164
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49962925910949707
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 165
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49790263175964355
# Data shape =  (518, 921, 3)
# Label =  66
# Processing frame # 166
# Original Frame is =  (720, 1280, 3)
# Processed Frame is =  (750, 1333, 3)
# processing time:  0.49863290786743164
# Data shape =  (518, 921, 3)
# Label =  66
# --- 101.67539620399475 seconds ---
# Finished reading video
# Wrote video to  out_uber_trimmed_xyz_RetinaNet_2.avi
# Frames with person []
