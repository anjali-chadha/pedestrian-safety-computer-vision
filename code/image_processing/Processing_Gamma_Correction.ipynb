# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skvideo.io import FFmpegWriter 
# %matplotlib inline

# %%
start = 1
fps = '30'
cap = cv2.VideoCapture('/scratch/group/puneet-anjali-group/videos/uber_trimmed.mp4')
outfile = './uber-videos/gamma_corrected_equalv2.mp4'

# %% [markdown]
# ## Create a video with gamma correction

# %%
def histogram_equalizer(input_video, outfile, fps=30):
    vidcap = cv2.VideoCapture(input_video)
   
    writer = FFmpegWriter(outfile, outputdict={'-r': fps})
    writer = FFmpegWriter(outfile)
    
    while True:
        ret, image = vidcap.read()
        if not ret: break
        image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        equ = cv2.equalizeHist(image)
        writer.writeFrame(equ)
    writer.close()

# %%
input_video = '/scratch/group/puneet-anjali-group/videos/uber_trimmed.mp4'
outfile = './uber-videos/uber_equalizer.mp4'
histogram_equalizer(input_video, outfile)

# %%
def foo(img):
    #-----Reading the image-----------------------------------------------------
    #img = cv2.imread('Dog.jpg', 1)
    #-----Converting image to LAB Color model----------------------------------- 
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    lab = cv2.equalizeHist(lab)

    #-----Splitting the LAB image to different channels-------------------------
    l, a, b = cv2.split(lab)

    #-----Applying CLAHE to L-channel-------------------------------------------
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    #-----Merge the CLAHE enhanced L-channel with the a and b channel-----------
    limg = cv2.merge((cl,a,b))
    #-----Converting image from LAB Color model to RGB model--------------------
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    return final

# %%
cnt = 0
sec = 0
while True:
    ret, f = cap.read()
    if not ret: break
    #f = cv2.cvtColor(f, cv2.COLOR_BGR2GRAY)
    #f = cv2.equalizeHist(f)
    #clahe = cv2.createCLAHE()
    #cl1 = clahe.apply(f)
    #f = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    f = foo(f)
    cnt = 0
    res = 0.05*f
    res = res.astype(np.float64)
    writer.writeFrame(f)
writer.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b2c5d53f1e0b> in <module>()
#       2 sec = 0
#       3 while True:
# ----> 4     ret, f = cap.read()
#       5     if not ret: break
#       6     #f = cv2.cvtColor(f, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cap' is not defined

# %% [markdown]
# ## Gamma Corrected Video (Greeen)

# %%
def histogram_equalizer_green(input_video, outfile, fps=30):
    vidcap = cv2.VideoCapture(input_video)
   
    writer = FFmpegWriter(outfile, outputdict={'-r': fps})
    writer = FFmpegWriter(outfile)wt
    
    while True:
        ret, image = vidcap.read()
        if not ret: break
        image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        equ = cv2.equalizeHist(image)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(equ)
        plt.savefig('frame.jpg')
        equ=cv2.imread('frame.jpg')
        writer.writeFrame(equ)
    writer.close()

# %%
input_video = '/scratch/group/puneet-anjali-group/videos/uber_trimmed.mp4'
outfile = './uber-videos/uber_equalizer_green.mp4'
histogram_equalizer_green(input_video, outfile)

# %% [markdown]
# # STOP!

# %%
#-----Reading the image-----------------------------------------------------
img = cv2.imread('Frames/frame71.jpg', 0)
plt.xticks([])
plt.yticks([])
plt.figure(figsize=(80,90))
plt.imshow(img)

# %%
equ = cv2.equalizeHist(img)
cv2.imwrite('frame71_equalized.jpg', equ)
plt.imshow(equ)
plt.savefig('frame71_equalized.jpg')

# %%
clahe = cv2.createCLAHE(clipLimit=1000.0, tileGridSize=(10, 10))
cl1 = clahe.apply(equ)

res = np.hstack((img,equ, cl1))
plt.imshow(res)

# %%
#-----Converting image to LAB Color model----------------------------------- 
lab= cv2.cvtColor(equ, cv2.COLOR_BGR2LAB)
plt.imshow(lab)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-5cbfe6120309> in <module>()
#       1 #-----Converting image to LAB Color model-----------------------------------
# ----> 2 lab= cv2.cvtColor(equ, cv2.COLOR_BGR2LAB)
#       3 plt.imshow(lab)
#
# error: /tmp/build/80754af9/opencv_1512491964794/work/modules/imgproc/src/color.cpp:11134: error: (-215) (scn == 3 || scn == 4) && (depth == 0 || depth == 5) in function cvtColor

# %%
#-----Splitting the LAB image to different channels-------------------------
l, a, b = cv2.split(lab)
plt.imshow(l) # L channel

# %%
plt.imshow(a)

# %%
plt.imshow( b)

# %%
#-----Applying CLAHE to L-channel-------------------------------------------
clahe = cv2.createCLAHE(clipLimit=100.0, tileGridSize=(1, 1))
cl = clahe.apply(l)
plt.imshow(cl) #'CLAHE output'

# %%
 cv2.imwrite('./Frames_Gamma/frame88.jpg', cl)
# Out:
# True

# %% [markdown]
# ##### -----Merge the CLAHE enhanced L-channel with the a and b channel-----------
# limg = cv2.merge((cl,a,b))
# plt.imshow( limg) #'limg',

# %%
#-----Converting image from LAB Color model to RGB model--------------------
final = cv2.cvtColor(img, cv2.COLOR_LAB2BGR)
plt.imshow(final) #'final'
#_____END_____#

# %%
img = cv2.imread('Frames/frame142.jpg',1)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-bypjredd-side
plt.imshow(res)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-1dc2befe8ded> in <module>()
#       1 img = cv2.imread('Frames/frame142.jpg',1)
# ----> 2 equ = cv2.equalizeHist(img)
#       3 res = np.hstack((img,equ)) #stacking images side-bypjredd-side
#       4 plt.imshow(res)
#
# error: /tmp/build/80754af9/opencv_1512491964794/work/modules/imgproc/src/histogram.cpp:3913: error: (-215) _src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function equalizeHist

# %%
clahe = cv2.createCLAHE(clipLimit=1000.0, tileGridSize=(10, 10))
cl1 = clahe.apply(res)

plt.imshow(cl1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-8e2dc98d73af> in <module>()
#       1 clahe = cv2.createCLAHE(clipLimit=1000.0, tileGridSize=(10, 10))
# ----> 2 cl1 = clahe.apply(res)
#       3
#       4 plt.imshow(cl1)
#
# NameError: name 'res' is not defined
